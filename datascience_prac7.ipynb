# %% [markdown]
# <a href="https://colab.research.google.com/github/6181PRADEEPPARIHAR/Data_Science/blob/main/datascience_prac7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img= mpimg.imread('images.jpg')
plt.imshow(img)

# %%
import pandas as pd
data=pd.DataFrame({'marks':[19,22,30,49,55],
                  'roll_no.':[2014,202,2033,204,205],
                  'name':['dipesh','suresh','ramesh','mahesh','rajesh'],
                  })

print(data)
# Out:
#    marks  roll_no.    name
# 0     19      2014  dipesh
# 1     22       202  suresh
# 2     30      2033  ramesh
# 3     49       204  mahesh
# 4     55       205  rajesh

# %%
data.isnull()
# Out:
#    sr.no  roll_no.   Name
# 0  False     False  False
# 1  False     False  False
# 2  False     False  False
# 3  False     False  False
# 4  False     False  False

# %%
data.isnull().sum()
# Out:
# sr.no       0
# roll_no.    0
# Name        0
# dtype: int64

# %%
data.describe()
# Out:
#           sr.no    roll_no.
# count  5.000000    5.000000
# mean   3.000000  203.000000
# std    1.581139    1.581139
# min    1.000000  201.000000
# 25%    2.000000  202.000000
# 50%    3.000000  203.000000
# 75%    4.000000  204.000000
# max    5.000000  205.000000

# %%
data.describe(include='object')
# Out:
#           Name
# count        5
# unique       5
# top     dipesh
# freq         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sr.no     5 non-null      int64
#  1   roll_no.  5 non-null      int64
#  2   Name      5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
data.nunique()
# Out:
# sr.no       5
# roll_no.    5
# Name        5
# dtype: int64

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['name']
# Out:
# 0    dipesh
# 1    suresh
# 2    ramesh
# 3    mahesh
# 4    rajesh
# Name: name, dtype: object

# %%
data['name'].value_counts()
# Out:
# dipesh    1
# suresh    1
# ramesh    1
# mahesh    1
# rajesh    1
# Name: name, dtype: int64

# %%
data1=pd.DataFrame({'class':['a','b','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b','a','b']})

# %%
data1.nunique()
# Out:
# class    2
# dtype: int64

# %%
data1.value_counts()
# Out:
# class
# b        36
# a        35
# dtype: int64

# %%
data['marks'].mean()
# Out:
# 3.0

# %%
data['marks'].var()
# Out:
# 2.5

# %%
corre=data.corr()
# Out:
# <ipython-input-78-0b7006ea44c3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corre=data.corr()

# %%
import seaborn as sns
sns.heatmap(corre,annot=True,fmt='.1f',cmap='plasma')
# Out:
# <Axes: >
